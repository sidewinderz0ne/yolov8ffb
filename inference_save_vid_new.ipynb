mp4",
    # "C:\\Users\\DELL\\Documents\\video\\OB\\27_03_24_NBE_OB.mp4"
    # "C:\\Users\\DELL\\Documents\\video\\OB\\03_04_24_NBE_OB.mp4",
    # "C:\\Users\\DELL\\Documents\\video\\OB\\04_04_24_NBE_OB.mp4"
    # "C:\\Users\\DELL\\Documents\\video\\OB\\29_04_24_NBE_OB.mp4",
    # "C:\\Users\\DELL\\Documents\\video\\OB\\19_04_24_NBE_OB.mp4"
    # "C:\\Users\\DELL\\Documents\\video\\OC\\03_04_24_NBE_OC.mp4",
    # "C:\\Users\\DELL\\Documents\\video\\OC\\08_04_24_NBE_OC.mp4",
    # "C:\\Users\\DELL\\Documents\\video\\OC\\12_04_24_NBE_OC.mp4",
    # "C:\\Users\\DELL\\Documents\\video\\OC\\13_3_2024_NBE_OC.mp4",
    # "C:\\Users\\DELL\\Documents\\video\\OC\\18_04_24_NBE_OC.mp4",
    # "C:\\Users\\DELL\\Documents\\video\\OC\\19_03_2024_NBE_OC.mp4",
    # "C:\\Users\\DELL\\Documents\\video\\OC\\21_03_2024_NBE_OC.mp4",
    # "C:\\Users\\DELL\\Documents\\video\\OC\\22_03_24_NBE_OC.mp4",
    # "C:\\Users\\DELL\\Documents\\video\\OC\\23_04_24_NBE_OC.mp4",
    # "C:\\Users\\DELL\\Documents\\video\\OC\\25_03_24_NBE_OC.mp4",
    # "C:\\Users\\DELL\\Documents\\video\\OC\\30_04-24_NBE_OC.mp4",
    # "C:\\Users\\DELL\\Documents\\video\\OC\\Merge_Grading_6_Feb_OC.mp4",
    # "C:\\Users\\DELL\\Documents\\video\\OC\\Merge_Grading_20_jan_OC.mp4",
    # "C:\\Users\\DELL\\Documents\\video\\OC\\Merge_grading_24_jan_OC.mp4"
    # "C:\\Users\\DELL\\Documents\\video\\OD\\02_04_24_NBE_OD.mp4",
    # "C:\\Users\\DELL\\Documents\\video\\OD\\29_04_24_NBE_OD.mp4"
    
    
    # "/home/grading/sampel_video_sampling/22_05_24_NBE_OB.mp4"
    # "/home/grading/sampel_video_sampling/22_05_24_NBE_OD.mp4"
    # "/home/grading/sampel_video_sampling/21_05_24_NBE_OB.mp4",
    # "/home/grading/sampel_video_sampling/21_05_24_NBE_OC.mp4",
    # "/home/grading/sampel_video_sampling/20_05_24_NBE_OB.mp4",
    # "/home/grading/sampel_video_sampling/20_05_24_NBE_OC.mp4"
    # "/home/grading/sampel_video_sampling/30_04_24_NBE_OD.mp4",
    # "/home/grading/sampel_video_sampling/30_04_24_NBE_OC.mp4",
    # "/home/grading/sampel_video_sampling/29_04_24_NBE_OB.mp4",
    # "/home/grading/sampel_video_sampling/29_04_24_NBE_OD.mp4",
    # "/home/grading/sampel_video_sampling/23_04_24_NBE_OC.mp4",
    # "/home/grading/sampel_video_sampling/19_04_24_NBE_OB.mp4",
    # "/home/grading/sampel_video_sampling/19_04_24_NBE_OA.mp4",
    # "/home/grading/sampel_video_sampling/18_04_24_NBE_OC.mp4",
    # "/home/grading/sampel_video_sampling/18_04_24_NBE_OD.mp4",
    # "/home/grading/sampel_video_sampling/17_04_24_NBE_OB.mp4",
    # "/home/grading/sampel_video_sampling/17_04_24_NBE_OD.mp4",
    # "/home/grading/sampel_video_sampling/15_04_24_NBE_OD.mp4",
    # "/home/grading/sampel_video_sampling/15_04_24_NBE_OD.mp4",
    # "/home/grading/sampel_video_sampling/16_04_24_NBE_OA.mp4",
    # "/home/grading/sampel_video_sampling/16_04_24_NBE_OB.mp4",
    # "/home/grading/sampel_video_sampling/15_04_24_NBE_OD.mp4",
    # "/home/grading/sampel_video_sampling/15_04_24_NBE_OB.mp4",
    # "/home/grading/sampel_video_sampling/12_04_24_NBE_OB.mp4",
    # "/home/grading/sampel_video_sampling/12_04_24_NBE_OC.mp4",
    # "/home/grading/sampel_video_sampling/08_04_24_NBE_OA.mp4",
    # "/home/grading/sampel_video_sampling/08_04_24_NBE_OC.mp4"
    # "/home/grading/sampel_video_sampling/04_04_24_NBE_OD.mp4",
    # "/home/grading/sampel_video_sampling/04_04_24_NBE_OB.mp4",
    # "/home/grading/sampel_video_sampling/03_04_24_NBE_OC.mp4",
    # "/home/grading/sampel_video_sampling/03_04_24_NBE_OB.mp4",
    # "/home/grading/sampel_video_sampling/02_04_24_NBE_OD.mp4",
    # "/home/grading/sampel_video_sampling/02_04_24_NBE_OA.mp4",
    # "/home/grading/sampel_video_sampling/28_03_24_NBE_OB.mp4",
    # "/home/grading/sampel_video_sampling/28_03_24_NBE_OA.mp4",
    # "/home/grading/sampel_video_sampling/27_03_24_NBE_OD.mp4",
    # "/home/grading/sampel_video_sampling/27_03_24_NBE_OB.mp4",
    # "/home/grading/sampel_video_sampling/25_03_24_NBE_OC.mp4",
    # "/home/grading/sampel_video_sampling/25_03_24_NBE_OB.mp4",
    # "/home/grading/sampel_video_sampling/22_03_24_NBE_OC.mp4",
    # "/home/grading/sampel_video_sampling/21_03_24_NBE_OB.mp4",
    # "/home/grading/sampel_video_sampling/21_03_2024_NBE_OC.mp4",
    # "/home/grading/sampel_video_sampling/20_03_2024_NBE_OA.mp4",
    # "/home/grading/sampel_video_sampling/19_03_2024_NBE_OA.mp4",
    # "/home/grading/sampel_video_sampling/19_03_2024_NBE_OC.mp4",
    # "/home/grading/sampel_video_sampling/18_03_24_NBE_OB.mp4",
    # "/home/grading/sampel_video_sampling/18_03_2024_NBE_OA.mp4",
    # "/home/grading/sampel_video_sampling/15_03_24_NBE_OB.mp4",
    # "/home/grading/sampel_video_sampling/15_03_2024_NBE_OD.mp4",
    # "/home/grading/sampel_video_sampling/13_3_2024_NBE_OD.mp4",
    # "/home/grading/sampel_video_sampling/13_3_2024_NBE_OC.mp4",
    # "/home/grading/sampel_video_sampling/12_3_24_NBE_OA.mp4",
    # "/home/grading/sampel_video_sampling/12_3_24_NBE_OB.mp4",
    # "/home/grading/sampel_video_sampling/Merge_Grading_6_Feb_OD.mp4",
    # "/home/grading/sampel_video_sampling/Merge_Grading_6_Feb_OC.mp4",
    # "/home/grading/sampel_video_sampling/Merge_Grading_5_Feb_OB.mp4",
    # "/home/grading/sampel_video_sampling/Merge_Grading_5_Feb_OA.mp4",
    # "/home/grading/sampel_video_sampling/Merge_Grading_31_Jan_OA.mp4",
    # "/home/grading/sampel_video_sampling/Merge_Grading_31_Jan_OD.mp4",
    # "/home/grading/sampel_video_sampling/Merge_Grading_30_Jan_OA.mp4",
    # "/home/grading/sampel_video_sampling/Merge_Grading_29_Jan_OB.mp4",
    # "/home/grading/sampel_video_sampling/Merge_Grading_29_Jan_OA.mp4",
    # "/home/grading/sampel_video_sampling/Merge_Grading_23_jan_OA.mp4",
    # "/home/grading/sampel_video_sampling/Merge_Grading_24_jan_OB.mp4",
    # "/home/grading/sampel_video_sampling/Merge_grading_24_jan_OC.mp4",
    # "/home/grading/sampel_video_sampling/Merge_Grading_20_jan_OC.mp4"
    "C:\\Users\\DELL\\Documents\\yolov8ffb\\video\\Sampel_Video_Scm.mp4"
          ]

models = [
    # "/home/grading/yolov8/weight/yolov8n_gabungan_total_sampling/weights/best.pt",
    # "/home/grading/yolov8/weight/yolov8n_gabungan_total_sampling/weights/last.pt",
    # "/home/grading/yolov8/weight/yolov5nu_1280_gabungan_total_sampling/weights/best.pt",
    # "/home/grading/yolov8/weight/yolov5nu_1280_gabungan_total_sampling/weights/last.pt",
    # "/home/grading/yolov8/weight/2024-01-23-09-04_yolov5su_1280/train/weights/best.pt",
    # "/home/grading/yolov8/weight/2024-01-23-09-04_yolov5su_1280/train/weights/last.pt",
    # "/home/grading/yolov8/weight/2024-01-22-07-25_yolov8s_1280/train/weights/best.pt",
    # "/home/grading/yolov8/weight/2024-01-22-07-25_yolov8s_1280/train/weights/last.pt",

    # "/home/grading/yolov8/weight/yolov8n_gabungan_total_sampling/train/weights/best.pt",
    # "/home/grading/yolov8/weight/yolov8n_gabungan_total_sampling/train/weights/last.pt",
    # "/home/grading/yolov8/weight/yolov5nu_1280_gabungan_total_sampling/train/weights/best.pt",
    # "/home/grading/yolov8/weight/yolov5nu_1280_gabungan_total_sampling/train/weights/last.pt",
    # "/home/grading/yolov8/weight/2024
    # "/home/grading/yolov8/weight/2024-04-23-17-10_yolov5nu_640_sampling_only_revisi/train/weights/best.pt",
    # "/home/grading/yolov8/weight/2024-04-23-17-10_yolov5nu_640_sampling_only_revisi/train/weights/last.pt"

    # "C:\\Users\\DELL\\Documents\\model\\yolov8n_1280_sampling\\best.pt",
    # "C:\\Users\\DELL\\Documents\\model\\yolov8s_1280_sampling_only_revisi\\best.pt",
    # "C:\\Users\\DELL\\Documents\\model\\yolov8n_1280_sampling_only_revisi\\best.pt",
    # "C:\\Users\\DELL\\Documents\\model\\yolov5su_1280_sampling_only_revisi\\best.pt",
    # "C:\\Users\\DELL\\Documents\\model\\yolov5nu_1280_sampling_only_revisi\\best.pt"
    "C:\\Users\\DELL\\Documents\\python\\train_data\\yolov5nu_1280\\weights\\best.pt",
    "C:\\Users\\DELL\\Documents\\python\\train_data\\2024-09-19-07-13_yolov8s_1280\\train\\weights\\best.pt",
    "C:\\Users\\DELL\\Documents\\python\\train_data\\2024-09-17-09-18_yolov5su_1280\\train\\weights\\best.pt",
    "C:\\Users\\DELL\\Documents\\python\\train_data\\yolov5nu_640\\weights\\best.pt",
    "C:\\Users\\DELL\\Documents\\python\\train_data\\2024-09-16-02-52_yolov8s_640\\train\\weights\\best.pt",
    "C:\\Users\\DELL\\Documents\\python\\train_data\\2024-09-15-02-35_yolov8n_1280\\train\\weights\\best.pt",
    "C:\\Users\\DELL\\Documents\\python\\train_data\\2024-09-14-18-59_yolov8n_640\\train\\weights\\best.pt",
    "C:\\Users\\DELL\\Documents\\python\\train_data\\2024-09-13-18-16_yolov5su_640\\train\\weights\\best.pt"
    
         ]

# models = [
#     "/home/grading/yolov8/weight/2024-04-22-21-43_yolov8s_1280_sampling_only_revisi/train/weights/best.pt",
#     "/home/grading/yolov8/weight/2024-04-22-21-43_yolov8s_1280_sampling_only_revisi/train/weights/last.pt",
#     "/home/grading/yolov8/weight/2024-04-22-23-35_yolov8s_640_sampling_only_revisi/train/weights/best.pt",
#     "/home/grading/yolov8/weight/2024-04-22-23-35_yolov8s_640_sampling_only_revisi/train/weights/last.pt",
#     "/home/grading/yolov8/weight/2024-04-22-19-45_yolov8n_640_sampling_only_revisi/train/weights/best.pt",
#     "/home/grading/yolov8/weight/2024-04-22-19-45_yolov8n_640_sampling_only_revisi/train/weights/last.pt",
#     "/home/grading/yolov8/weight/2024-04-22-18-30_yolov8n_1280_sampling_only_revisi/train/weights/best.pt",
#     "/home/grading/yolov8/weight/2024-04-22-18-30_yolov8n_1280_sampling_only_revisi/train/weights/last.pt",
#     "/home/grading/yolov8/weight/2024-04-22-17-51_yolov5su_640_sampling_only_revisi/train/weights/best.pt",
#     "/home/grading/yolov8/weight/2024-04-22-17-51_yolov5su_640_sampling_only_revisi/train/weights/last.pt",
#     "/home/grading/yolov8/weight/2024-04-22-16-10_yolov5su_1280_sampling_only_revisi/train/weights/best.pt",
#     "/home/grading/yolov8/weight/2024-04-22-16-10_yolov5su_1280_sampling_only_revisi/train/weights/last.pt",
#     "/home/grading/yolov8/weight/2024-04-22-20-25_yolov5nu_1280_sampling_only_revisi/train/weights/best.pt",
#     "/home/grading/yolov8/weight/2024-04-22-20-25_yolov5nu_1280_sampling_only_revisi/train/weights/last.pt",
#     "/home/grading/yolov8/weight/2024-04-23-17-10_yolov5nu_640_sampling_only_revisi/train/weights/best.pt",
#     "/home/grading/yolov8/weight/2024-04-23-17-10_yolov5nu_640_sampling_only_revisi/train/weights/last.pt"

# ]

# sources = ["/home/grading/sampel_video_sampling/Merge_Grading_6_Feb_OD.mp4",
#           "/home/grading/sampel_video_sampling/Merge_Grading_6_Feb_OC.mp4"]

loop = 0
total_loops = len(models) * len(imgszs) * len(sources) * len(rois) * len(thres) * len(ious)
start_time = time.time()

for model in models:
    for imgsz in imgszs:
        for source in sources:
            # Get the .txt file corresponding to the source
            txt_file = source.replace(".mp4", ".txt")

            for roi in rois:
                for thre in thres:
                    for iou in ious:
                        # Increment loop count for every iteration, skipped or not
                        loop += 1

                        # Construct the parameters string that would be logged in the .txt file
                        params_string = f"{model},[{imgsz}],{roi},{thre},{iou}"

                        # Check if the current combination of parameters already exists in the .txt file
                        if os.path.exists(txt_file):
                            with open(txt_file, 'r') as f:
                                if any(params_string in line for line in f):
                                    print(f"Skipping: {params_string} (already exists in {txt_file})")
                                    continue  # Skip to the next loop iteration

                        # Update progress tracking
                        elapsed_time = time.time() - start_time
                        estimated_remaining_time = (elapsed_time / loop) * (total_loops - loop)
                        percentage = (loop / total_loops) * 100
                        print(f"Progress: {percentage:.2f}% ({loop}/{total_loops}), ETR: {estimated_remaining_time:.2f} seconds")

                        # Construct and run the command
                        command = f'python 11-track-master.py --mode "testing" --roi {roi} --conf_thres {thre} --source {source} --yolo_model {model} --imgsz {imgsz} --iou_thres {iou}'
                        os.system(command)
# Out:
# Skipping: C:\Users\DELL\Documents\python\train_data\yolov5nu_1280\weights\best.pt,[1280],0.3,0.2,0.5 (already exists in C:\Users\DELL\Documents\yolov8ffb\video\Sampel_Video_Scm.txt)
# Skipping: C:\Users\DELL\Documents\python\train_data\yolov5nu_1280\weights\best.pt,[1280],0.3,0.45,0.5 (already exists in C:\Users\DELL\Documents\yolov8ffb\video\Sampel_Video_Scm.txt)
# Skipping: C:\Users\DELL\Documents\python\train_data\yolov5nu_1280\weights\best.pt,[800],0.3,0.2,0.5 (already exists in C:\Users\DELL\Documents\yolov8ffb\video\Sampel_Video_Scm.txt)
# Skipping: C:\Users\DELL\Documents\python\train_data\yolov5nu_1280\weights\best.pt,[800],0.3,0.45,0.5 (already exists in C:\Users\DELL\Documents\yolov8ffb\video\Sampel_Video_Scm.txt)
# Skipping: C:\Users\DELL\Documents\python\train_data\2024-09-19-07-13_yolov8s_1280\train\weights\best.pt,[1280],0.3,0.2,0.5 (already exists in C:\Users\DELL\Documents\yolov8ffb\video\Sampel_Video_Scm.txt)
# ...
