# %%
cd /home/grading/yolov8/
# Out:
# /home/grading/yolov8

# %%
# models = ["yolov5lu", "yolov5mu", "yolov5nu", "yolov5su", "yolov5xu","yolov8l","yolov8m","yolov8n","yolov8s","yolov8x"]
# models = ["yolov8n", "yolov8l", "yolov5mu", "yolov5su", "yolov5nu","yolov8lu","yolov5m6u","yolov5n6u","yolov5s6u","yolov5l6u"]
# models = ["yolov5su","yolov8n","yolov5nu", "yolov8s"]
models = ["yolov5nu"]
img_sizes = [640]
# img_sizes = [1280]
batch_size = 5
# excludeModels = [["yolov5mu","640"],["yolov5nu","640"],["yolov5nu","1280"],["yolov5su","640"],["yolov5su","1280"],["yolov5xu","640"]]
excludeModels = [["yolov5mu","640"]]

import subprocess
from datetime import datetime

# Initialize a list to store the last 100 lines of output
output_buffer = []

for model in models:
    for img_size in img_sizes:
        skip_model = False  # Flag to skip the current model and image size combination
        
        for excludeModel in excludeModels:
            if img_size == int(excludeModel[1]) and model == excludeModel[0]:
                skip_model = True
                break  # Exit the inner loop if a match is found
        
        if skip_model:
            continue  # Skip the current model and image size combination

        # Get the current date and time
        current_datetime = datetime.now()
        
        # Format the current date and time as "YYYY-MM-DD"
        formatted_date = current_datetime.strftime("%Y-%m-%d-%H-%M")
        
        project = f"{formatted_date}_{model}_{img_size}"
        command = f"yolo task=detect mode=train project={project} epochs=500 data=class.yaml model={model} imgsz={img_size} batch={batch_size} patience=20 resume=False"

        process = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)

        while True:
            output = process.stdout.readline()
            if output == '' and process.poll() is not None:
                break
            if output:
                # Add the current line to the output buffer
                output_buffer.append(output.strip())
                # Keep only the last 100 lines in the buffer
                if len(output_buffer) > 100:
                    output_buffer.pop(0)

# Print the last 100 lines from the output buffer
for line in output_buffer:
    print(line)
# Out:
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  21%|██        | 27/129 [00:01<00:04, 25.45it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  23%|██▎       | 30/129 [00:01<00:03, 25.64it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  26%|██▌       | 33/129 [00:01<00:03, 25.69it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  28%|██▊       | 36/129 [00:01<00:03, 25.64it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  30%|███       | 39/129 [00:01<00:03, 25.27it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  33%|███▎      | 42/129 [00:01<00:03, 25.26it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  35%|███▍      | 45/129 [00:01<00:03, 25.29it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  37%|███▋      | 48/129 [00:01<00:03, 25.34it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  40%|███▉      | 51/129 [00:01<00:03, 25.17it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  42%|████▏     | 54/129 [00:02<00:02, 25.41it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  44%|████▍     | 57/129 [00:02<00:02, 26.04it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  47%|████▋     | 60/129 [00:02<00:02, 26.67it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  49%|████▉     | 63/129 [00:02<00:02, 27.29it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  51%|█████     | 66/129 [00:02<00:02, 25.37it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  53%|█████▎    | 69/129 [00:02<00:02, 23.69it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  56%|█████▌    | 72/129 [00:02<00:02, 22.59it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  58%|█████▊    | 75/129 [00:02<00:02, 24.04it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  60%|██████    | 78/129 [00:03<00:02, 25.11it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  63%|██████▎   | 81/129 [00:03<00:01, 24.65it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  68%|██████▊   | 88/129 [00:03<00:01, 34.68it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  71%|███████▏  | 92/129 [00:03<00:01, 29.04it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  74%|███████▍  | 96/129 [00:03<00:01, 28.46it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  77%|███████▋  | 99/129 [00:03<00:01, 25.82it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  79%|███████▉  | 102/129 [00:03<00:01, 25.96it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  81%|████████▏ | 105/129 [00:04<00:00, 26.58it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  84%|████████▎ | 108/129 [00:04<00:00, 25.80it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  86%|████████▌ | 111/129 [00:04<00:00, 25.92it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  88%|████████▊ | 114/129 [00:04<00:00, 26.07it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  91%|█████████ | 117/129 [00:04<00:00, 24.85it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  93%|█████████▎| 120/129 [00:04<00:00, 25.42it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  95%|█████████▌| 123/129 [00:04<00:00, 25.71it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  98%|█████████▊| 126/129 [00:04<00:00, 25.55it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 129/129 [00:04<00:00, 26.72it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 129/129 [00:04<00:00, 26.00it/s]
# all       1284      10552      0.636      0.655      0.685        0.5
# Stopping training early as no improvement observed in last 20 epochs. Best results observed at epoch 38, best model saved as best.pt.
# To update EarlyStopping(patience=20) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 58 epochs completed in 0.869 hours.
# Optimizer stripped from 2024-04-23-17-10_yolov5nu_640/train/weights/last.pt, 5.3MB
# Optimizer stripped from 2024-04-23-17-10_yolov5nu_640/train/weights/best.pt, 5.3MB
#
# Validating 2024-04-23-17-10_yolov5nu_640/train/weights/best.pt...
# Ultralytics YOLOv8.1.40 🚀 Python-3.11.8 torch-2.1.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3070, 7959MiB)
# YOLOv5n summary (fused): 193 layers, 2504114 parameters, 0 gradients, 7.1 GFLOPs
#
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/129 [00:00<?, ?it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   2%|▏         | 2/129 [00:00<00:42,  2.97it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   2%|▏         | 3/129 [00:03<02:43,  1.29s/it]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   3%|▎         | 4/129 [00:05<03:02,  1.46s/it]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   5%|▌         | 7/129 [00:05<01:11,  1.71it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   9%|▊         | 11/129 [00:05<00:34,  3.47it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  11%|█         | 14/129 [00:05<00:22,  5.10it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  13%|█▎        | 17/129 [00:05<00:16,  6.92it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  16%|█▌        | 20/129 [00:05<00:12,  9.01it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  18%|█▊        | 23/129 [00:05<00:09, 11.46it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  20%|██        | 26/129 [00:05<00:07, 13.72it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  22%|██▏       | 29/129 [00:06<00:06, 16.03it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  25%|██▍       | 32/129 [00:06<00:05, 18.28it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  27%|██▋       | 35/129 [00:06<00:04, 19.20it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  29%|██▉       | 38/129 [00:06<00:04, 20.41it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  32%|███▏      | 41/129 [00:06<00:04, 21.05it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  34%|███▍      | 44/129 [00:06<00:03, 22.17it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  36%|███▋      | 47/129 [00:06<00:03, 23.41it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  39%|███▉      | 50/129 [00:06<00:03, 23.32it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  41%|████      | 53/129 [00:07<00:03, 24.26it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  43%|████▎     | 56/129 [00:07<00:02, 25.14it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  46%|████▌     | 59/129 [00:07<00:02, 24.75it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  48%|████▊     | 62/129 [00:07<00:02, 24.60it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  50%|█████     | 65/129 [00:07<00:02, 23.87it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  53%|█████▎    | 68/129 [00:07<00:02, 22.88it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  55%|█████▌    | 71/129 [00:07<00:02, 21.94it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  57%|█████▋    | 74/129 [00:07<00:02, 22.70it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  60%|█████▉    | 77/129 [00:08<00:02, 23.82it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  62%|██████▏   | 80/129 [00:08<00:02, 24.27it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  67%|██████▋   | 87/129 [00:08<00:01, 34.46it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  71%|███████   | 91/129 [00:08<00:01, 30.65it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  74%|███████▎  | 95/129 [00:08<00:01, 30.61it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  77%|███████▋  | 99/129 [00:08<00:01, 24.55it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  79%|███████▉  | 102/129 [00:08<00:01, 25.22it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  81%|████████▏ | 105/129 [00:09<00:00, 26.15it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  84%|████████▎ | 108/129 [00:09<00:00, 25.96it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  86%|████████▌ | 111/129 [00:09<00:00, 25.12it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  88%|████████▊ | 114/129 [00:09<00:00, 23.49it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  91%|█████████ | 117/129 [00:09<00:00, 22.99it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  93%|█████████▎| 120/129 [00:09<00:00, 23.71it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  95%|█████████▌| 123/129 [00:09<00:00, 24.73it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  98%|█████████▊| 126/129 [00:09<00:00, 25.29it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 129/129 [00:09<00:00, 25.85it/s]
# Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 129/129 [00:09<00:00, 12.91it/s]
# all       1284      10552      0.635      0.655      0.694      0.506
# unripe       1284       2036      0.606      0.844      0.796      0.647
# ripe       1284       4488      0.739      0.776      0.833       0.67
# overripe       1284       1604      0.584      0.633      0.649      0.507
# empty_bunch       1284        708      0.601      0.565      0.636      0.463
# abnormal       1284        748      0.512       0.52       0.54      0.401
# long_stalk       1284        968      0.766       0.59      0.713       0.35
# Speed: 0.1ms preprocess, 0.8ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to 2024-04-23-17-10_yolov5nu_640/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train
